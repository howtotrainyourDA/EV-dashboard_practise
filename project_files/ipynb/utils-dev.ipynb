# %%
import pandas as pd

# %%
sales_url = "https://api.iea.org/evs?parameters=EV%20sales&category=Historical&mode=Cars&csv=true"
sales_df = pd.read_csv(sales_url)


sales_df.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
def load_sales_data():
    sales_url = "https://api.iea.org/evs?parameters=EV%20sales&category=Historical&mode=Cars&csv=true"
    sales_df = pd.read_csv(sales_url)
    cleaned_sales_df = sales_df[sales_df["parameter"] == "EV sales"]
    cleaned_sales_df = cleaned_sales_df[cleaned_sales_df["powertrain"] == "BEV"]
    cleaned_sales_df.drop(['mode', 'powertrain', 'parameter', 'category', "unit"], axis=1, inplace=True)
    return cleaned_sales_df

    #alt: cols_to_keep = ['region', 'year', 'value']
    #cleaned_sales_df = cleaned_sales_df[cols_to_keep]

new_sales = load_sales_data()
new_sales.head(20)
# Out:
#         region  year    value
# 0    Australia  2011     49.0
# 9    Australia  2012    170.0
# 10   Australia  2013    190.0
# 21   Australia  2014    370.0
# 22   Australia  2015    760.0
# 33   Australia  2016    670.0
# 34   Australia  2017   1200.0
# 45   Australia  2018   1800.0
# 51   Australia  2019   6300.0
# 52   Australia  2020   5200.0
# 64   Australia  2021  17000.0
# 67   Australia  2022  33000.0
# 80   Australia  2023  87000.0
# 93     Austria  2013    650.0
# 94     Austria  2014   1700.0
# 108    Austria  2015   1700.0
# 109    Austria  2016   3800.0
# 123    Austria  2017   5400.0
# 124    Austria  2018   6800.0
# 139    Austria  2019   9300.0

# %%
charging_url = "https://api.iea.org/evs?parameters=EV%20charging%20points&category=Historical&mode=EV&csv=true"
charging_df = pd.read_csv(charging_url)

charging_df.head(20)
# Out:
#        region    category           parameter mode               powertrain  \
# 0   Australia  Historical  EV charging points   EV  Publicly available fast
# 1   Australia  Historical  EV charging points   EV  Publicly available slow
# 2   Australia  Historical  EV charging points   EV  Publicly available fast
# 3   Australia  Historical  EV charging points   EV  Publicly available slow
# 4   Australia  Historical  EV charging points   EV  Publicly available slow
# 5   Australia  Historical  EV charging points   EV  Publicly available slow
# 6   Australia  Historical  EV charging points   EV  Publicly available fast
# 7   Australia  Historical  EV charging points   EV  Publicly available slow
# 8   Australia  Historical  EV charging points   EV  Publicly available fast
# 9   Australia  Historical  EV charging points   EV  Publicly available slow
# 10  Australia  Historical  EV charging points   EV  Publicly available fast
# ...

# %%
for col in charging_df.columns:
    print(charging_df[col].unique())
# Out:
# ['Australia' 'Austria' 'Belgium' 'Brazil' 'Canada' 'Chile' 'China'
#  'Denmark' 'EU27' 'Europe' 'Finland' 'France' 'Germany' 'Greece' 'Iceland'
#  'India' 'Indonesia' 'Israel' 'Italy' 'Japan' 'Korea' 'Mexico'
#  'Netherlands' 'New Zealand' 'Norway' 'Poland' 'Portugal' 'South Africa'
#  'Spain' 'Sweden' 'Switzerland' 'Thailand' 'Turkiye' 'United Kingdom'
#  'USA' 'World']
# ['Historical']
# ['EV charging points']
# ['EV']
# ['Publicly available fast' 'Publicly available slow']
# [2017 2018 2019 2020 2021 2022 2023 2011 2012 2013 2014 2015 2016 2010]
# ['charging points']
# [4.00000000e+01 4.40000000e+02 6.10000000e+01 6.70000000e+02
#  1.70000000e+03 2.30000000e+03 3.20000000e+02 2.00000000e+03
#  4.70000000e+02 2.10000000e+03 6.60000000e+02 1.00000001e-01
#  1.60000000e+03 8.90000000e+03 2.60000000e+03 1.30000000e+04
#  2.50000000e+03 1.50000000e+04 4.70000000e+01 3.30000000e+02
#  5.50000000e+01 5.60000000e+02 7.70000000e+01 1.30000000e+03
# ...
